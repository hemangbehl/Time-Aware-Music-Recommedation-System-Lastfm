# %%
# import the usual
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %%
#Music Data Loading
df = pd.read_csv(r"F:\Data_Repository\lastfm\userid-timestamp-artid-artname-traid-traname.tsv", sep="\t", error_bad_lines=False, header = None)
dfsmall = pd.read_csv(r"F:\Data_Repository\lastfm\usersha1-profile.tsv",sep='\t',names=['userId','gender','age','country','signupDate'])
data = pd.read_csv(r"F:\Data_Repository\lastfm\usersha1-artmbid-artname-plays.tsv",sep='\t',names=['userId','artistId','artist','plays'])
# Out:
# b'Skipping line 2120260: expected 6 fields, saw 8\n'
# b'Skipping line 2446318: expected 6 fields, saw 8\n'
# b'Skipping line 11141081: expected 6 fields, saw 8\n'
# b'Skipping line 11152099: expected 6 fields, saw 12\nSkipping line 11152402: expected 6 fields, saw 8\n'
# b'Skipping line 11882087: expected 6 fields, saw 8\n'
# b'Skipping line 12902539: expected 6 fields, saw 8\nSkipping line 12935044: expected 6 fields, saw 8\n'
# b'Skipping line 17589539: expected 6 fields, saw 8\n'

# %%
df.columns = ['userid', 'timestamp', 'artistid', 'artist', '1', 'song']

# %%
df[:100]
# Out:
#          userid             timestamp                              artistid  \
# 0   user_000001  2009-05-04T23:08:57Z  f1b1cf71-bd35-4e99-8624-24a6e15f133a
# 1   user_000001  2009-05-04T13:54:10Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 2   user_000001  2009-05-04T13:52:04Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 3   user_000001  2009-05-04T13:42:52Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 4   user_000001  2009-05-04T13:42:11Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 5   user_000001  2009-05-04T13:38:31Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 6   user_000001  2009-05-04T13:33:28Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 7   user_000001  2009-05-04T13:23:45Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 8   user_000001  2009-05-04T13:19:22Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 9   user_000001  2009-05-04T13:13:38Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 10  user_000001  2009-05-04T13:06:09Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 11  user_000001  2009-05-04T13:00:48Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 12  user_000001  2009-05-04T12:55:34Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 13  user_000001  2009-05-04T12:51:26Z  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 14  user_000001  2009-05-03T15:48:25Z  ba2f4f3b-0293-4bc8-bb94-2f73b5207343
# 15  user_000001  2009-05-03T15:37:56Z  ba2f4f3b-0293-4bc8-bb94-2f73b5207343
# 16  user_000001  2009-05-03T15:14:53Z  a16e47f5-aa54-47fe-87e4-bb8af91a9fdd
# 17  user_000001  2009-05-03T15:10:18Z  463a94f1-2713-40b1-9c88-dcc9c0170cae
# 18  user_000001  2009-05-03T15:04:31Z  ad0811ea-e213-451d-b22f-fa1a7f9e0226
# 19  user_000001  2009-05-03T14:56:25Z  309e2dfc-678e-4d09-a7a4-8eab9525b669
# 20  user_000001  2009-05-03T14:50:51Z  6f3d4a7b-45b2-4c08-9306-8d271e92cb4f
# 21  user_000001  2009-05-03T14:46:29Z  463a94f1-2713-40b1-9c88-dcc9c0170cae
# 22  user_000001  2009-05-03T14:39:20Z  45bdb5be-ec03-484f-b58d-d22afc944b24
# 23  user_000001  2009-05-03T14:34:06Z  3c174d9d-139b-4fa7-8f0b-ae8eceb4271c
# 24  user_000001  2009-05-03T14:28:02Z  f945fc79-fb9e-4e3e-b60a-f4a90f5a6d38
# 25  user_000001  2009-05-03T14:20:15Z  ce559a88-58ba-4d8a-8456-9177412d609c
# 26  user_000001  2009-05-03T14:07:40Z  ce559a88-58ba-4d8a-8456-9177412d609c
# 27  user_000001  2009-05-03T14:01:15Z  ce559a88-58ba-4d8a-8456-9177412d609c
# 28  user_000001  2009-05-03T13:56:25Z  ce559a88-58ba-4d8a-8456-9177412d609c
# 29  user_000001  2009-05-03T13:47:20Z  ce559a88-58ba-4d8a-8456-9177412d609c
# ..          ...                   ...                                   ...
# 70  user_000001  2009-05-02T12:55:00Z  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 71  user_000001  2009-05-01T14:27:23Z  56a70482-5528-4bef-8da2-a33cf098ce9b
# 72  user_000001  2009-05-01T14:07:16Z  56a70482-5528-4bef-8da2-a33cf098ce9b
# 73  user_000001  2009-05-01T13:55:27Z  56a70482-5528-4bef-8da2-a33cf098ce9b
# 74  user_000001  2009-05-01T12:45:46Z  eab8228c-a9c8-4ddb-a93d-ffca74a379bf
# 75  user_000001  2009-05-01T12:18:14Z  c64bbb9f-1acb-40fa-abb3-2ca0246bdee1
# 76  user_000001  2009-05-01T12:09:59Z  f945fc79-fb9e-4e3e-b60a-f4a90f5a6d38
# 77  user_000001  2009-05-01T12:04:30Z  a3934f47-c4cc-4e73-8b37-ce41775797d4
# 78  user_000001  2009-05-01T11:58:15Z                                   NaN
# 79  user_000001  2009-05-01T11:55:00Z  05fd92f7-60d7-4fe9-95e2-7ff597e755db
# 80  user_000001  2009-05-01T11:50:01Z  6685bdd9-37f3-4323-8f7c-0e7bb9103e6d
# 81  user_000001  2009-05-01T10:07:40Z  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 82  user_000001  2009-05-01T10:03:53Z  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 83  user_000001  2009-05-01T09:58:14Z  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 84  user_000001  2009-05-01T09:52:59Z  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 85  user_000001  2009-05-01T09:47:29Z  1e48cdae-b68d-4cd0-bfba-a78ad30d2e9f
# 86  user_000001  2009-05-01T09:42:25Z  a3934f47-c4cc-4e73-8b37-ce41775797d4
# 87  user_000001  2009-05-01T09:36:10Z                                   NaN
# 88  user_000001  2009-05-01T09:32:54Z  05fd92f7-60d7-4fe9-95e2-7ff597e755db
# 89  user_000001  2009-05-01T09:27:56Z  6685bdd9-37f3-4323-8f7c-0e7bb9103e6d
# 90  user_000001  2009-05-01T09:22:23Z  88c7bc11-a2a7-4acc-8bad-cbe3e693b41f
# 91  user_000001  2009-05-01T09:17:36Z  c74ee320-1daa-43e6-89ee-f71070ee9e8f
# 92  user_000001  2009-05-01T09:12:21Z                                   NaN
# 93  user_000001  2009-05-01T09:08:00Z  0ae49abe-d6af-44fa-8ab0-b9ace5690e6f
# 94  user_000001  2009-05-01T09:03:40Z  36081add-59bd-4603-ae06-5b46ffe8f8df
# 95  user_000001  2009-05-01T08:58:19Z                                   NaN
# 96  user_000001  2009-05-01T08:52:36Z  1e68e986-e1f7-42ef-be43-086c858db02e
# 97  user_000001  2009-05-01T08:45:19Z  c2fc3098-b9a5-41ab-b897-e6d67b097dfa
# 98  user_000001  2009-05-01T08:41:49Z  278db520-adb6-4d27-a770-7539fa2e33b7
# 99  user_000001  2009-05-01T08:37:58Z  c6971fd2-7a18-4a31-87aa-45e6ccb48ce1
#
#                            artist                                     1  \
# 0                       Deep Dish                                   NaN
# 1                            坂本龍一                                   NaN
# 2                            坂本龍一                                   NaN
# 3                            坂本龍一                                   NaN
# 4                            坂本龍一                                   NaN
# 5                            坂本龍一                                   NaN
# 6                            坂本龍一                                   NaN
# 7                            坂本龍一                                   NaN
# 8                            坂本龍一                                   NaN
# 9                            坂本龍一                                   NaN
# 10                           坂本龍一  f7c1f8f8-b935-45ed-8fc8-7def69d92a10
# 11                           坂本龍一                                   NaN
# 12                           坂本龍一  475d4e50-cebb-4cd0-8cd4-c3df97987962
# 13                           坂本龍一                                   NaN
# 14                     Underworld  dc394163-2b78-4b56-94e4-658597a29ef8
# 15                     Underworld  340d9a0b-9a43-4098-b116-9f79811bd508
# 16                Ennio Morricone  0b04407b-f517-4e00-9e6a-494795efc73e
# 17                        Minus 8  4e78efc4-e545-47af-9617-05ff816d86e2
# 18                      Beanfield  fb51d2c4-cc69-4128-92f5-77ec38d66859
# 19                       Dj Linus  4277434f-e3c2-41ae-9ce3-23fd157f9347
# 20                      Alif Tree  1151b040-8022-4965-96d2-8a4605ce456c
# 21                        Minus 8  f78c95a8-9256-4757-9a9f-213df5c6854e
# 22                        Wei-Chi  c4fc8802-d186-4c4d-85cd-d5d063b935c2
# 23                      Marsmobil  7217acaf-0f12-4cc0-95da-4fbe17b399dd
# 24                          Karma  b79e44f0-2a27-4f50-8a08-ce959a48c9c0
# 25                      Masomenos                                   NaN
# 26                      Masomenos                                   NaN
# 27                      Masomenos                                   NaN
# 28                      Masomenos                                   NaN
# 29                      Masomenos                                   NaN
# ..                            ...                                   ...
# 70                       Marc Mac                                   NaN
# 71                      Minilogue                                   NaN
# 72                      Minilogue                                   NaN
# 73                      Minilogue                                   NaN
# 74                          Clark  935e9356-19cc-467e-8bc5-f1c2e07caebc
# 75                         Losoul  d1de63b3-fb80-46bc-befa-8e55076b379a
# 76                          Karma  e7d6d338-5e90-4133-8f8b-2a2e63f2a5eb
# 77                      Lisa Shaw                                   NaN
# 78                  Rocket Empire                                   NaN
# 79                 Samantha James  e1696a4f-e1b2-4727-a7df-d5b4207ffd52
# 80                          Gelka  fc89d5bf-a04c-41c9-836d-924e64302076
# 81                       Marc Mac                                   NaN
# 82                       Marc Mac                                   NaN
# 83                       Marc Mac                                   NaN
# 84                       Marc Mac                                   NaN
# 85                       Marc Mac                                   NaN
# 86                      Lisa Shaw                                   NaN
# 87                  Rocket Empire                                   NaN
# 88                 Samantha James  e1696a4f-e1b2-4727-a7df-d5b4207ffd52
# 89                          Gelka  fc89d5bf-a04c-41c9-836d-924e64302076
# 90                         Rithma                                   NaN
# 91              Impossible Beings  952f360d-d678-40b2-8a64-18b4fa4c5f8f
# 92                         Nicken                                   NaN
# 93            Bombay Bicycle Club  56a5d259-220d-4bf7-9416-99c365ec6103
# 94         Woolfy Vs. Projections  da8e7bec-f1ce-4664-a229-1c2320ea5e05
# 95                      Ivan Enot                                   NaN
# 96  J. Boogie'S Dubtronic Science  66eb69ab-a5e3-4d17-92a6-754c898e4c86
# 97                  Home & Garden  820c1ffc-5a54-4d68-9603-765b83531578
# 98                 Kissey Asplund                                   NaN
# 99                     Pc Synergy                                   NaN
#
#                                                  song
# 0          Fuck Me Im Famous (Pacha Ibiza)-09-28-2007
# 1                   Composition 0919 (Live_2009_4_15)
# 2                                Mc2 (Live_2009_4_15)
# 3                             Hibari (Live_2009_4_15)
# 4                                Mc1 (Live_2009_4_15)
# 5                        To Stanford (Live_2009_4_15)
# 6                      Improvisation (Live_2009_4_15)
# 7                            Glacier (Live_2009_4_15)
# 8                          Parolibre (Live_2009_4_15)
# 9                     Bibo No Aozora (Live_2009_4_15)
# 10                           The Last Emperor (Theme)
# 11                          Happyend (Live_2009_4_15)
# 12                            Tibetan Dance (Version)
# 13                   Behind The Mask (Live_2009_4_15)
# 14                       Boy, Boy, Boy (Switch Remix)
# 15             Crocodile (Innervisions Orchestra Mix)
# 16                Ninna Nanna In Blu (Raw Deal Remix)
# 17                                     Elysian Fields
# 18                                 Planetary Deadlock
# 19                  Good Morning Love Coffee Is Ready
# 20                                     Deadly Species
# 21                                        Cold Fusion
# 22                                             Clouds
# 23                                       Sovatex 2055
# 24                                        Beach Towel
# 25                                              Eight
# 26                                              Seven
# 27                                                Six
# 28                                               Five
# 29                                               Four
# ..                                                ...
# 70                                           Backspin
# 71                            Animals (Luciano Remix)
# 72                            Animals (Luciano Remix)
# 73                            Animals (Luciano Remix)
# 74                                      Growls Garden
# 75                                          The Crush
# 76                    Are We? (Feat. Michelle Amador)
# 77                      Inside My Love (Extended Mix)
# 78                                 Simmer Down Jammie
# 79                                          Amber Sky
# 80                                         Rasta Baby
# 81                                           Headspin
# 82                                        Jazz Flares
# 83                                             Freeze
# 84                                           Footwork
# 85                                           Backspin
# 86                      Inside My Love (Extended Mix)
# 87                                 Simmer Down Jammie
# 88                                          Amber Sky
# 89                                         Rasta Baby
# 90  (The Only) Dark In The Light (Steve Sampling Mix)
# 91                                         Dois Pólos
# 92                                              Lifeb
# 93          You Already Know (Feat. Kathryn Williams)
# 94                                           Carry On
# 95                               Grooves Of The Heart
# 96  Leave It All Behind (Feat. The Rebirth & Aima ...
# 97                          Someday (Feat. Lisa Shaw)
# 98                          Move Me [Feat. Soliloquy]
# 99                                       Ready 2 Wear
#
# [100 rows x 6 columns]

# %%
data.head()
# Out:
#                                      userId  \
# 0  00000c289a1829a808ac09c00daf10bc3c4e223b
# 1  00000c289a1829a808ac09c00daf10bc3c4e223b
# 2  00000c289a1829a808ac09c00daf10bc3c4e223b
# 3  00000c289a1829a808ac09c00daf10bc3c4e223b
# 4  00000c289a1829a808ac09c00daf10bc3c4e223b
#
#                                artistId                artist  plays
# 0  3bd73256-3905-4f3a-97e2-8b341527f805       betty blowtorch   2137
# 1  f2fb0ff0-5679-42ec-a55c-15109ce6e320             die Ärzte   1099
# 2  b3ae82c2-e60b-4551-a76d-6620f1b456aa     melissa etheridge    897
# 3  3d6bbeb7-f90e-4d10-b440-e153c0d10b53             elvenking    717
# 4  bbd2ffd7-17f4-4506-8572-c1ea58c3f9a8  juliette & the licks    706

# %%
df['time'] = pd.to_datetime(df['timestamp'])

# %%
df.drop(['timestamp'], axis=1, inplace=True)

# %%
df.head()
# Out:
#         userid                              artistid     artist    1  \
# 0  user_000001  f1b1cf71-bd35-4e99-8624-24a6e15f133a  Deep Dish  NaN
# 1  user_000001  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8       坂本龍一  NaN
# 2  user_000001  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8       坂本龍一  NaN
# 3  user_000001  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8       坂本龍一  NaN
# 4  user_000001  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8       坂本龍一  NaN
#
#                                          song                time
# 0  Fuck Me Im Famous (Pacha Ibiza)-09-28-2007 2009-05-04 23:08:57
# 1           Composition 0919 (Live_2009_4_15) 2009-05-04 13:54:10
# 2                        Mc2 (Live_2009_4_15) 2009-05-04 13:52:04
# 3                     Hibari (Live_2009_4_15) 2009-05-04 13:42:52
# 4                        Mc1 (Live_2009_4_15) 2009-05-04 13:42:11

# %% [markdown]
# ### Removing artist name and song id (possibly) from the user_songs_df dataframe

# %%
user_songs_df = df.drop(['artist'], axis=1, inplace=False)

# %%
user_songs_df.columns = ['userid', 'artistid', 'songid', 'song', 'time']

# %%
user_songs_df = user_songs_df.drop(['songid'], axis=1, inplace=False)

# %%
user_songs_df.head()
# Out:
#         userid                              artistid  \
# 0  user_000001  f1b1cf71-bd35-4e99-8624-24a6e15f133a
# 1  user_000001  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 2  user_000001  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 3  user_000001  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 4  user_000001  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
#
#                                          song                time
# 0  Fuck Me Im Famous (Pacha Ibiza)-09-28-2007 2009-05-04 23:08:57
# 1           Composition 0919 (Live_2009_4_15) 2009-05-04 13:54:10
# 2                        Mc2 (Live_2009_4_15) 2009-05-04 13:52:04
# 3                     Hibari (Live_2009_4_15) 2009-05-04 13:42:52
# 4                        Mc1 (Live_2009_4_15) 2009-05-04 13:42:11

# %%
user_songs_df['song'].nunique()
# Out:
# 1083471

# %%
# pd.merge(user_songs_df, songs_df, on='song')

# %%
# user_songs_df[user_songs_df['userid'] == 'user_000001']['song'].value_counts()[:10].plot()

# %%
# user_songs_df['userid'].nunique()

# %%
# user_songs_df['song'].nunique()

# %%
# user_songs_df['song'].value_counts()[:20].plot(kind='bar')

# %%
# user_songs_df['song'].value_counts()[:100].plot(kind='bar')

# %%
# user_songs_df.groupby("userid").filter(lambda x: len(x) > 10000).shape

# %%
# user_songs_df.groupby("userid").filter(lambda x: len(x) > 100000).shape

# %%
# user_songs_df.groupby("userid").filter(lambda x: len(x) > 1000000).shape

# %%
# user_songs_df.groupby("userid").filter(lambda x: len(x) > 1000).shape

# %%
def get_song_unique_count(song_column):
#     print("len of list : "+str(len(song_column)))
#     print("len of set : "+str(len(set(song_column))))
    return len(set(song_column))

# %%
# user_songs_df.groupby("userid").filter(lambda x: get_song_unique_count(x['song'])>1000).shape

# %%
# user_songs_df.groupby("userid").filter(lambda x: get_song_unique_count(x['song'])>5000)['userid'].nunique()

# %%
# user_songs_df.groupby("userid").filter(lambda x: get_song_unique_count(x['song'])>5000)['song'].nunique()

# %%
# user_songs_df.groupby("userid").filter(lambda x: get_song_unique_count(x['song'])>1000)['song'].nunique()

# %%
# user_songs_df.groupby("userid").filter(lambda x: get_song_unique_count(x['song'])>10000)['song'].nunique()

# %%
# df_songs_heard_10_users = user_songs_df.groupby("song").filter(lambda x: get_song_unique_count(x['userid'])>10)

# %%
# df_songs_heard_10_users = user_songs_df.groupby("song")

# %%
# df_songs_heard_10_users.head()

# %%
# df_songs_heard_10_users['song'].nunique()

# %%
# df_songs_heard_10_users['userid'].nunique()

# %%
# %%time
#df_songs_heard_100_users = user_songs_df.groupby("song").filter(lambda x: get_song_unique_count(x['userid'])>100)
# Out:
# Wall time: 0 ns

# %%
# %%time
#df_user_songs_grp = user_songs_df.groupby(["userid","song"])
# Out:
# Wall time: 0 ns

# %%
#df_user_songs_grp.first()

# %%
#df_user_songs_grp['artistid']

# %%
# filter_morethan10 = df_user_songs_grp['artistid'].filter(lambda x: len(x) >= 10)

# %%
# %%time
user_song_df_count = user_songs_df.groupby(["userid","song"]).size().reset_index(name="Count")
# Out:
# Wall time: 15.5 s

# %%
user_song_df_count.head(10)
# Out:
#         userid                                               song  Count
# 0  user_000001                                  '84 Pontiac Dream     14
# 1  user_000001           (All I Wanted Was To Make You) Feel Good      3
# 2  user_000001                                  (D)Ecaying Beauty      1
# 3  user_000001                                    (Far From) Home      1
# 4  user_000001                     (Get Off Your) High Horse Lady      1
# 5  user_000001                                   (It'S Just) Talk     13
# 6  user_000001                                       (Nice Dream)      1
# 7  user_000001  (The Only) Dark In The Light (Steve Sampling Mix)      4
# 8  user_000001                                          +Pantonal      2
# 9  user_000001                                 ...Short Wave Lies     11

# %%
#user_song_df_count.first

# %%
user_song_df_count.nunique()
# Out:
# userid        992
# song      1083471
# Count         534
# dtype: int64

# %%
songs_df = pd.DataFrame({'song':user_songs_df['song'],'artistid':user_songs_df['artistid']})
songs_df.drop_duplicates(subset='song', inplace=True, keep='first')

# %%
songs_df.shape
# Out:
# (1083472, 2)

# %%
songs_df.head()
# Out:
#                                          song  \
# 0  Fuck Me Im Famous (Pacha Ibiza)-09-28-2007
# 1           Composition 0919 (Live_2009_4_15)
# 2                        Mc2 (Live_2009_4_15)
# 3                     Hibari (Live_2009_4_15)
# 4                        Mc1 (Live_2009_4_15)
#
#                                artistid
# 0  f1b1cf71-bd35-4e99-8624-24a6e15f133a
# 1  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 2  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 3  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8
# 4  a7f7df4a-77d8-4f12-8acd-5c60c93f4de8

# %%
data.head()
# Out:
#                                      userId  \
# 0  00000c289a1829a808ac09c00daf10bc3c4e223b
# 1  00000c289a1829a808ac09c00daf10bc3c4e223b
# 2  00000c289a1829a808ac09c00daf10bc3c4e223b
# 3  00000c289a1829a808ac09c00daf10bc3c4e223b
# 4  00000c289a1829a808ac09c00daf10bc3c4e223b
#
#                                artistId                artist  plays
# 0  3bd73256-3905-4f3a-97e2-8b341527f805       betty blowtorch   2137
# 1  f2fb0ff0-5679-42ec-a55c-15109ce6e320             die Ärzte   1099
# 2  b3ae82c2-e60b-4551-a76d-6620f1b456aa     melissa etheridge    897
# 3  3d6bbeb7-f90e-4d10-b440-e153c0d10b53             elvenking    717
# 4  bbd2ffd7-17f4-4506-8572-c1ea58c3f9a8  juliette & the licks    706

# %%
data['plays'].max()
# Out:
# 419157

# %%
data = pd.merge(data, dfsmall, on='userId', how='left')

# %%
data.head()
# Out:
#                                      userId  \
# 0  00000c289a1829a808ac09c00daf10bc3c4e223b
# 1  00000c289a1829a808ac09c00daf10bc3c4e223b
# 2  00000c289a1829a808ac09c00daf10bc3c4e223b
# 3  00000c289a1829a808ac09c00daf10bc3c4e223b
# 4  00000c289a1829a808ac09c00daf10bc3c4e223b
#
#                                artistId                artist  plays gender  \
# 0  3bd73256-3905-4f3a-97e2-8b341527f805       betty blowtorch   2137      f
# 1  f2fb0ff0-5679-42ec-a55c-15109ce6e320             die Ärzte   1099      f
# 2  b3ae82c2-e60b-4551-a76d-6620f1b456aa     melissa etheridge    897      f
# 3  3d6bbeb7-f90e-4d10-b440-e153c0d10b53             elvenking    717      f
# 4  bbd2ffd7-17f4-4506-8572-c1ea58c3f9a8  juliette & the licks    706      f
#
#     age  country   signupDate
# 0  22.0  Germany  Feb 1, 2007
# 1  22.0  Germany  Feb 1, 2007
# 2  22.0  Germany  Feb 1, 2007
# 3  22.0  Germany  Feb 1, 2007
# 4  22.0  Germany  Feb 1, 2007

# %%
user_plays = pd.DataFrame()
